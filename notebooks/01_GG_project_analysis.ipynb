# %% [markdown]
# ## Data Analysis Project: Analyzing Instagram Engagement
#
# ### Project Summary:
#
# This project analyzes a dataset related to the engagement of posts on the Instagram account of a fictional company. The goal is to identify the factors that most influence engagement, with a focus on the tags used.
#
# The dataset covers the period from the account's creation until March 27th and includes metrics such as likes, comments, and interactions. Views were disregarded, as the focus of the analysis is on direct engagement metrics. This project concentrates on data preparation and exploratory analysis to generate insights into the performance of the posts.

# %%
import pandas as pd

from src.config import ORIGINAL_DATA

df_insta = pd.read_excel(ORIGINAL_DATA)

df_insta.head()
# Out:
#     Type       Date  Likes  Comments    Views           Tags People Campaign  \
# 0  Photo 2021-09-11   2858        16      NaN           Shop      N        N
# 1  Photo 2021-09-11   2930        28      NaN  Shop/Products      N        N
# 2  Photo 2021-09-11   2807         9      NaN           Shop      N        N
# 3  Video 2021-09-12   5115        49  82878.0       Products      N        N
# 4  Photo 2021-09-13   4392        45      NaN       Products      Y        N
#
#   Carousel  Interactions
# 0      NaN           2874
# 1      NaN           2958
# 2      NaN           2816
# 3      NaN           5164
# 4      NaN           4437

# %% [markdown]
# The fictional company asked us to disregard the "views" column, so we removed it from the dataset.

# %%
df_insta = df_insta.drop("Views", axis=1)

df_insta.head()
# Out:
#     Type       Date  Likes  Comments           Tags People Campaign Carousel  \
# 0  Photo 2021-09-11   2858        16           Shop      N        N      NaN
# 1  Photo 2021-09-11   2930        28  Shop/Products      N        N      NaN
# 2  Photo 2021-09-11   2807         9           Shop      N        N      NaN
# 3  Video 2021-09-12   5115        49       Products      N        N      NaN
# 4  Photo 2021-09-13   4392        45       Products      Y        N      NaN
#
#    Interactions
# 0           2874
# 1           2958
# 2           2816
# 3           5164
# 4           4437

# %%
df_insta.tail()
# Out:
#      Type       Date  Likes  Comments                         Tags People  \
# 47   IGTV 2022-03-12   5489        77     Usages tips/New Products      Y
# 48  Photo 2022-03-20  29084       479  Celebration date/Promotions      Y
# 49  Photo 2022-03-22   9087       106                          NaN      Y
# 50  Photo 2022-03-26  16551       186                          NaN      Y
# 51   IGTV 2022-03-27   4934        65         Usages tips/Products      Y
#
#    Campaign Carousel  Interactions
# 47        N      NaN           5566
# 48        Y      NaN          29563
# 49        Y      NaN           9193
# 50        N      NaN          16737
# 51        N      NaN           4999

# %%
df_insta.shape
# Out:
# (52, 9)

# %%
df_insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           52 non-null     object
#  1   Date           52 non-null     datetime64[ns]
#  2   Likes          52 non-null     int64
#  3   Comments       52 non-null     int64
#  4   Tags           44 non-null     object
#  5   People         52 non-null     object
#  6   Campaign       52 non-null     object
#  7   Carousel       8 non-null      object
#  8   Interactions   52 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 3.8+ KB

# %% [markdown]
# To Do: Analyze why the "carousel" column has only 8 non-null values.

# %%
df_insta["Carousel"].value_counts()
# Out:
# Carousel
# Y    8
# Name: count, dtype: int64

# %%
df_insta.loc[df_insta["Carousel"].isnull()].head()
# Out:
#     Type       Date  Likes  Comments           Tags People Campaign Carousel  \
# 0  Photo 2021-09-11   2858        16           Shop      N        N      NaN
# 1  Photo 2021-09-11   2930        28  Shop/Products      N        N      NaN
# 2  Photo 2021-09-11   2807         9           Shop      N        N      NaN
# 3  Video 2021-09-12   5115        49       Products      N        N      NaN
# 4  Photo 2021-09-13   4392        45       Products      Y        N      NaN
#
#    Interactions
# 0           2874
# 1           2958
# 2           2816
# 3           5164
# 4           4437

# %%
df_insta.loc[df_insta["Carousel"].notnull()].head(10)
# Out:
#      Type       Date  Likes  Comments              Tags People Campaign  \
# 5   Photo 2021-09-17   5359        62      New Products      N        Y
# 8   Photo 2021-09-27   6355        89          Products      Y        N
# 12  Photo 2021-10-21   6166        55      New Products      Y        Y
# 21  Photo 2021-12-23   8328        93          Products      Y        N
# 25  Photo 2022-01-02  12193       138      New Products      Y        N
# 26  Photo 2022-01-08  24585       354  Celebration date      Y        Y
# 28  Photo 2022-01-15   9936       119      New Products      Y        N
# 40  Photo 2022-02-21  21621       213       Influencers      Y        Y
#
#    Carousel  Interactions
# 5         Y           5421
# 8         Y           6444
# 12        Y           6221
# 21        Y           8421
# 25        Y          12331
# 26        Y          24939
# 28        Y          10055
# 40        Y          21834

# %% [markdown]
# To Do: Assume that the null values in the "Carousel" column represent "N", since all non-null values are "Y".

# %%
df_insta.loc[df_insta["Carousel"].isnull(), "Carousel"] = "N"

# %%
df_insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           52 non-null     object
#  1   Date           52 non-null     datetime64[ns]
#  2   Likes          52 non-null     int64
#  3   Comments       52 non-null     int64
#  4   Tags           44 non-null     object
#  5   People         52 non-null     object
#  6   Campaign       52 non-null     object
#  7   Carousel       52 non-null     object
#  8   Interactions   52 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 3.8+ KB

# %%
df_insta["Carousel"].value_counts()
# Out:
# Carousel
# N    44
# Y     8
# Name: count, dtype: int64

# %%
df_insta["Type"].value_counts()
# Out:
# Type
# Photo    36
# Video     6
# Reels     5
# IGTV      5
# Name: count, dtype: int64

# %% [markdown]
# To do: Use the describe() function to analyze the statistics of the numeric columns.

# %%
with pd.option_context("float_format", "{:.2f}".format):
    display(df_insta.describe(exclude=["datetime", "object"]))
# Out:
#          Likes  Comments  Interactions
# count    52.00     52.00          52.00
# mean  12262.73    189.50       12452.23
# std    8165.88    170.69        8299.39
# min    2807.00      9.00        2816.00
# 25%    5492.00     69.50        5562.50
# 50%    9603.00    128.00        9773.50
# 75%   17621.75    265.25       17920.75
# max   37351.00    852.00       37853.00

# %%
df_insta.sort_values(by="Likes", ascending=False).head()
# Out:
#      Type       Date  Likes  Comments                         Tags People  \
# 39  Photo 2022-02-17  37351       502                   Promotions      Y
# 30  Reels 2022-01-24  29981       502                       Trends      Y
# 48  Photo 2022-03-20  29084       479  Celebration date/Promotions      Y
# 33  Photo 2022-02-06  24655       186                  Influencers      Y
# 26  Photo 2022-01-08  24585       354             Celebration date      Y
#
#    Campaign Carousel  Interactions
# 39        Y        N          37853
# 30        Y        N          30483
# 48        Y        N          29563
# 33        Y        N          24841
# 26        Y        Y          24939

# %%
df_insta.sort_values(by="Likes", ascending=True).head()
# Out:
#      Type       Date  Likes  Comments           Tags People Campaign Carousel  \
# 2   Photo 2021-09-11   2807         9           Shop      N        N        N
# 0   Photo 2021-09-11   2858        16           Shop      N        N        N
# 20  Photo 2021-12-16   2881        29       Products      N        N        N
# 1   Photo 2021-09-11   2930        28  Shop/Products      N        N        N
# 17  Video 2021-11-09   3213        60       Products      N        N        N
#
#     Interactions
# 2            2816
# 0            2874
# 20           2910
# 1            2958
# 17           3273

# %% [markdown]
# The 5 posts with the highest number of likes featured people and were part of campaigns, while the 5 posts with the lowest number of likes did not include people or were related to campaigns.
#
# This demonstrates that likes are directly related to the presence of people in the photos and the execution of campaigns.

# %%
pd.options.display.float_format = "{:,.2f}".format

# %% [markdown]
# To Do: Use the describe() function to calculate averages and correlate columns, in order to identify the elements most present in the posts that generated the highest engagement.

# %%
df_insta.groupby("Type")["Likes"].mean()
# Out:
# Type
# IGTV     6,833.40
# Photo   13,341.14
# Reels   14,873.00
# Video    8,141.50
# Name: Likes, dtype: float64

# %%
df_insta.groupby(["Type"])[["Likes", "Comments"]].mean().sort_values("Likes", ascending=False)
# Out:
#           Likes  Comments
# Type
# Reels 14,873.00    244.40
# Photo 13,341.14    193.42
# Video  8,141.50    166.83
# IGTV   6,833.40    133.60

# %% [markdown]
# The data indicates that it is worth investing in Reels and photo posts.

# %%
df_insta.groupby(["People"])[["Likes", "Comments"]].mean().sort_values("Likes", ascending=False)
# Out:
#            Likes  Comments
# People
# Y      14,664.55    230.50
# N       4,256.67     52.83

# %% [markdown]
# It was also observed that posts featuring people generate higher engagement.

# %%
df_insta.groupby(["Type", "People"])[["Likes", "Comments"]].mean().sort_values("Likes", ascending=False)
# Out:
#                  Likes  Comments
# Type  People
# Reels Y      20,832.00    342.00
# Video Y      16,409.50    370.00
# Photo Y      15,236.67    226.20
# IGTV  Y       6,833.40    133.60
# Reels N       5,934.50     98.00
# Video N       4,007.50     65.25
# Photo N       3,863.50     29.50

# %% [markdown]
# Videos featuring people also showed a high level of engagement.

# %%
df_insta.groupby(["Type", "People", "Campaign"])[["Likes", "Comments"]].mean().sort_values("Likes", 
                                                                                                   ascending=False)
# Out:
#                           Likes  Comments
# Type  People Campaign
# Reels Y      Y        24,801.00    388.50
# Photo Y      Y        19,809.47    298.33
# Video Y      Y        16,409.50    370.00
# Reels Y      N        12,894.00    249.00
# Photo Y      N        10,815.29    159.93
#              S         8,544.00     72.00
# IGTV  Y      N         6,833.40    133.60
# Reels N      N         5,934.50     98.00
# Photo N      Y         5,852.50     47.50
# Video N      N         4,007.50     65.25
# Photo N      N         2,869.00     20.50

# %% [markdown]
# In conclusion, Reels and photos are the most effective formats for engagement, especially when they include people.
#
# Videos stood out when associated with campaigns featuring people, even generating more comments than photos.

# %%
df_insta.groupby("Tags")["Likes"].mean()
# Out:
# Tags
# Celebration date              17,975.00
# Celebration date/Promotions   29,084.00
# Influencers                   15,197.29
# New Products                  11,619.57
# Products                       5,666.92
# Promotions                    26,645.50
# Shop                           2,832.50
# Shop/Products                  2,930.00
# Trends                        22,400.67
# Trends/Products               12,894.00
# Usages tips/New Products       5,703.50
# Usages tips/Products           7,586.67
# Name: Likes, dtype: float64

# %% [markdown]
# To Do: Split posts that have two or more tags into separate rows to facilitate analysis.

# %%
df_insta["Tags"] = df_insta["Tags"].str.split("/")

df_insta.head()
# Out:
#     Type       Date  Likes  Comments              Tags People Campaign  \
# 0  Photo 2021-09-11   2858        16            [Shop]      N        N
# 1  Photo 2021-09-11   2930        28  [Shop, Products]      N        N
# 2  Photo 2021-09-11   2807         9            [Shop]      N        N
# 3  Video 2021-09-12   5115        49        [Products]      N        N
# 4  Photo 2021-09-13   4392        45        [Products]      Y        N
#
#   Carousel  Interactions
# 0        N           2874
# 1        N           2958
# 2        N           2816
# 3        N           5164
# 4        N           4437

# %%
df_insta = df_insta.explode("Tags")
df_insta.head()
# Out:
#     Type       Date  Likes  Comments      Tags People Campaign Carousel  \
# 0  Photo 2021-09-11   2858        16      Shop      N        N        N
# 1  Photo 2021-09-11   2930        28      Shop      N        N        N
# 1  Photo 2021-09-11   2930        28  Products      N        N        N
# 2  Photo 2021-09-11   2807         9      Shop      N        N        N
# 3  Video 2021-09-12   5115        49  Products      N        N        N
#
#    Interactions
# 0           2874
# 1           2958
# 1           2958
# 2           2816
# 3           5164

# %%
df_insta.groupby("Tags")["Likes"].mean()
# Out:
# Tags
# Celebration date   20,752.25
# Influencers        15,197.29
# New Products       10,304.89
# Products            6,269.82
# Promotions         27,458.33
# Shop                2,865.00
# Trends             20,024.00
# Usages tips         6,833.40
# Name: Likes, dtype: float64

# %% [markdown]
# To Do: Assign elements to null rows in the "Tags" column.

# %%
df_insta.loc[df_insta["Tags"].isnull(), "Tags"]
# Out:
# 11    NaN
# 19    NaN
# 29    NaN
# 38    NaN
# 41    NaN
# 43    NaN
# 49    NaN
# 50    NaN
# Name: Tags, dtype: object

# %%
df_insta.loc[df_insta["Tags"].isnull(), "Tags"] = "No Tag"

# %%
df_insta.groupby("Tags")[["Likes", "Comments"]].mean().sort_values("Likes", ascending=False)
# Out:
#                      Likes  Comments
# Tags
# Promotions       27,458.33    531.00
# Celebration date 20,752.25    343.50
# Trends           20,024.00    352.25
# No Tag           15,347.88    207.75
# Influencers      15,197.29    161.71
# New Products     10,304.89    198.56
# Usages tips       6,833.40    133.60
# Products          6,269.82     94.12
# Shop              2,865.00     17.67

# %% [markdown]
# Posts related to promotions show the highest engagement, followed by those associated with holidays and trending content.

# %%
df_insta.groupby(["People", "Tags"])[["Likes", "Comments"]].mean().sort_values("Likes", ascending=False)
# Out:
#                             Likes  Comments
# People Tags
# Y      Promotions       27,458.33    531.00
#        Celebration date 20,752.25    343.50
#        Trends           20,024.00    352.25
#        No Tag           15,347.88    207.75
#        Influencers      15,197.29    161.71
#        New Products     10,923.12    215.62
#        Products          8,316.38    131.62
#        Usages tips       6,833.40    133.60
# N      New Products      5,359.00     62.00
#        Products          4,450.67     60.78
#        Shop              2,865.00     17.67

# %%
df_insta.groupby(["Campaign", "Tags"])[["Likes", "Comments"]].mean().sort_values("Likes", ascending=False)
# Out:
#                               Likes  Comments
# Campaign Tags
# Y        Promotions       33,217.50    490.50
#          Trends           22,400.67    386.67
#          Influencers      21,258.25    229.00
#          Celebration date 20,752.25    343.50
#          No Tag           16,850.75    257.75
# N        Promotions       15,940.00    612.00
#          No Tag           13,845.00    157.75
#          Trends           12,894.00    249.00
# Y        New Products     11,040.67    323.00
# N        New Products      9,937.00    136.33
# Y        Products          9,074.00     67.50
# S        Influencers       8,544.00     72.00
# N        Usages tips       6,833.40    133.60
#          Influencers       6,402.00     72.00
#          Products          5,895.93     97.67
#          Shop              2,865.00     17.67

# %% [markdown]
# ## Conclusions
#
# Using people in posts is essential for good engagement.
#
# Creating campaigns boosts brand visibility.
#
# Promotions is the most sought-after tag, but it should be used more strategically due to its cost.
#
# Using trending content also brings a lot of views to the brand.
#
# Leveraging special dates to promote the brand is a great marketing strategy.
#
# New products perform better when presented with other people.
#
# The shop tag, at first glance, does not help promote the brand, but it also hasn’t been used alongside people and campaigns, which have already been proven as excellent ways to reach a larger audience.
#
# There is still room for more types of posts that the brand hasn’t tried yet, such as campaigns with IGTV.
